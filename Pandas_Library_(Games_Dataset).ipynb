# %% [markdown]
# # **PANDAS (PYTHON LIBRARY)**
# We shall now test your skills in using Pandas package. We will be using the [games Dataset](https://www.kaggle.com/gutsyrobot/games-data/data) from Kaggle.

# %% [markdown]
# **Import pandas as pd.**

# %%
import pandas as pd

# %% [markdown]
# **Read games.csv as a dataframe called games.**

# %%
game=pd.read_csv("/content/games.csv")

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
game.head()
# Out:
#        id       type                                       name  \
# 0   12333  boardgame                          Twilight Struggle
# 1  120677  boardgame                              Terra Mystica
# 2  102794  boardgame                  Caverna: The Cave Farmers
# 3   25613  boardgame  Through the Ages: A Story of Civilization
# 4    3076  boardgame                                Puerto Rico
#
#    yearpublished  minplayers  maxplayers  playingtime  minplaytime  \
# 0         2005.0         2.0         2.0        180.0        180.0
# 1         2012.0         2.0         5.0        150.0         60.0
# 2         2013.0         1.0         7.0        210.0         30.0
# 3         2006.0         2.0         4.0        240.0        240.0
# 4         2002.0         2.0         5.0        150.0         90.0
#
#    maxplaytime  minage  users_rated  average_rating  bayes_average_rating  \
# 0        180.0    13.0        20113         8.33774               8.22186
# ...

# %% [markdown]
# **Use .info() method to find out total number of entries in dataset**

# %%
game.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81312 entries, 0 to 81311
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    81312 non-null  int64
#  1   type                  81312 non-null  object
#  2   name                  81271 non-null  object
#  3   yearpublished         81309 non-null  float64
#  4   minplayers            81309 non-null  float64
#  5   maxplayers            81309 non-null  float64
#  6   playingtime           81309 non-null  float64
#  7   minplaytime           81309 non-null  float64
#  8   maxplaytime           81309 non-null  float64
#  9   minage                81309 non-null  float64
#  10  users_rated           81312 non-null  int64
#  11  average_rating        81312 non-null  float64
#  12  bayes_average_rating  81312 non-null  float64
#  13  total_owners          81312 non-null  int64
# ...

# %%
game=game.rename(columns={"total_weights":"weight", "total_comments":"comments", "total_wishers":"wishers", "total_wanters": "wanters", "total_traders": "traders", "total_owners" : "owwners"})
game.head()
# Out:
#        id       type                                       name  \
# 0   12333  boardgame                          Twilight Struggle
# 1  120677  boardgame                              Terra Mystica
# 2  102794  boardgame                  Caverna: The Cave Farmers
# 3   25613  boardgame  Through the Ages: A Story of Civilization
# 4    3076  boardgame                                Puerto Rico
#
#    yearpublished  minplayers  maxplayers  playingtime  minplaytime  \
# 0         2005.0         2.0         2.0        180.0        180.0
# 1         2012.0         2.0         5.0        150.0         60.0
# 2         2013.0         1.0         7.0        210.0         30.0
# 3         2006.0         2.0         4.0        240.0        240.0
# 4         2002.0         2.0         5.0        150.0         90.0
#
#    maxplaytime  minage  users_rated  average_rating  bayes_average_rating  \
# 0        180.0    13.0        20113         8.33774               8.22186
# ...

# %% [markdown]
# **What is the mean playing\ time for all games put together ?**

# %%
game['playingtime'].mean()
# Out:
# 51.63478827682052

# %%
game['playingtime'].median()
# Out:
# 30.0

# %% [markdown]
# **What is the highest number of comments received for a game?**

# %%
game['comments'].max()
# Out:
# 11798

# %% [markdown]
# **What is the name of the game with id 1500?**

# %%
game[game['id']==1500]['name']
# Out:
# 10592    Zocken
# Name: name, dtype: object

# %% [markdown]
# **And which year was it published?**

# %%
game[game['id']==1500]['yearpublished']
# Out:
# 10592    1999.0
# Name: yearpublished, dtype: float64

# %% [markdown]
# **Remove Duplicates**

# %%
game = game.drop_duplicates()
game.head(5)
# Out:
#        id       type                                       name  \
# 0   12333  boardgame                          Twilight Struggle
# 1  120677  boardgame                              Terra Mystica
# 2  102794  boardgame                  Caverna: The Cave Farmers
# 3   25613  boardgame  Through the Ages: A Story of Civilization
# 4    3076  boardgame                                Puerto Rico
#
#    yearpublished  minplayers  maxplayers  playingtime  minplaytime  \
# 0         2005.0         2.0         2.0        180.0        180.0
# 1         2012.0         2.0         5.0        150.0         60.0
# 2         2013.0         1.0         7.0        210.0         30.0
# 3         2006.0         2.0         4.0        240.0        240.0
# 4         2002.0         2.0         5.0        150.0         90.0
#
#    maxplaytime  minage  users_rated  average_rating  bayes_average_rating  \
# 0        180.0    13.0        20113         8.33774               8.22186
# ...

# %% [markdown]
# **Which game has received highest number of comments?**

# %%
game[game['comments']==game['comments'].max()]
# Out:
#      id       type   name  yearpublished  minplayers  maxplayers  playingtime  \
# 165  13  boardgame  Catan         1995.0         3.0         4.0         90.0
#
#      minplaytime  maxplaytime  minage  users_rated  average_rating  \
# 165         90.0         90.0    10.0        53680         7.34303
#
#      bayes_average_rating  owwners  traders  wanters  wishers  comments  \
# 165               7.21171    73188     1071      391     3201     11798
#
#      weight  average_weight
# 165    5996          2.3712

# %% [markdown]
# **Which games have received least number of comments?**

# %%
game[game["comments"]==game["comments"].min()]
# Out:
#            id                type  \
# 13048     318           boardgame
# 13054     468           boardgame
# 13068     579           boardgame
# 13095     738           boardgame
# 13103     778           boardgame
# ...       ...                 ...
# 81307  184441  boardgameexpansion
# 81308  184442           boardgame
# 81309  184443           boardgame
# 81310  184449           boardgame
# 81311  184451           boardgame
#
#                                                     name  yearpublished  \
# 13048                                         Looney Leo            0.0
# 13054                                               Dump            0.0
# 13068                                      Field of Fire         2002.0
# 13095                                           Matheeno         2000.0
# 13103  Auction America: The Trivia Game for Any Colle...         2000.0
# ...                                                  ...            ...
# ...

# %% [markdown]
# **What was the average minage of all games per game "type"? (boardgame & boardgameexpansion)**

# %%
game.groupby('type').mean()['minage']
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1489             try:
# -> 1490                 result = self.grouper._cython_operation(
#    1491                     "aggregate",
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958         ngroups = self.ngroups
# --> 959         return cy_op.cython_operation(
#     960             values=values,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     656
# --> 657         return self._cython_op_ndim_compat(
#     658             values,
#
# ...

# %% [markdown]
# **How many unique games are there in the dataset?**

# %%
game['name'].nunique()

# %% [markdown]
# **How many boardgames and boardgameexpansions are there in the dataset?**

# %%
game['type'].value_counts()

# %% [markdown]
# **Is there a correlation between playing time and total comments for the games? - Use the .corr() function**

# %%
game[['playingtime','comments']].corr()

# %% [markdown]
# #**Part 2**
# ##**Data Visualization using Seaborn**##

# %%
import seaborn as sns
sns.set(color_codes=True)
import matplotlib.pyplot as plt

# %% [markdown]
# ### Drop na values for negating issues during visualization

# %%
game.dropna(inplace=True)

# %% [markdown]
# ### View the distance plot for minage

# %%
sns.histplot(data=game['minage'])
# Out:
# <Axes: xlabel='minage', ylabel='Count'>

# %% [markdown]
# ### Is there a linear relationship between Minage & average_rating?

# %%
sns.jointplot(data=game, x="minage", y="average_rating")

# %% [markdown]
# ### Compare the relationship between playingtime , minage and average rating using pairplot

# %%
sns.pairplot(data=game[['average_rating','playingtime', "minage"]])

# %% [markdown]
# ### Compare type of game and playingtime using a stripplot

# %%
sns.stripplot(data=game, x="type", y="playingtime")

# %% [markdown]
# ### Analyze the linear trend between playing time(less than 500 mins) and average_rating received for the same

# %%
sns.regplot(x='playingtime', y='average_rating', data=game[game['playingtime']<500])

# %%
sns.histplot(data=game, y='yearpublished' ,x='comments')
